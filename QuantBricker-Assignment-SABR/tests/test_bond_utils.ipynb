# %%
import sys, os
repo_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if repo_root not in sys.path:
    sys.path.insert(0, repo_root)
print("Added to sys.path:", repo_root)
from fixedincomelib import *
print("Fixed Income Library is loaded.")
# Out:
# Added to sys.path: /Users/tiffanyyan/Documents/GitHub/QuantBricks
# Fixed Income Library is loaded.

# %%
bond_specs = qfCreateBondSpecs(
    "91282CPZ8",
    parameters={
        "ISIN": "91282CPZ8",
        "BOND_CONVENTION": "USD-GOVT-BOND-FIXED",
        "ISSUE_DATE": "2026-02-17",
        "FIRST_ACCRUAL_DATE": "2026-02-15",
        "FIRST_COUPON_DATE": "2026-08-15",
        "MATURITY_DATE": "2036-02-15",
        "COUPON_RATE": 0.04125,
        "REDEMPTION_PERCENTAGE": 1.0,
    },
)

# %%
bond = qfCreateProductBond(
    name="91282CPZ8",
    trade_date=Date("2026-08-15"),
    buy_sell="LONG",
)

# %%
yield_bond = BondUtils.price_to_yield(bond, 100.6, clean=True)
yield_bond
# Out:
# (0.04007857376167731, 0.08007134575036458, 70.75565998756412)

# %%
clean_price = BondUtils.yield_to_price(bond, 0.04046910, clean=True)
clean_price
# Out:
# 99.61702773623983

# %%
BondUtils.accrued_interest_amount(bond)
# Out:
# 0.6837016574585632
