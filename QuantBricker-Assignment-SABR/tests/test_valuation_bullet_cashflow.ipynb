# %%
import sys, os
repo_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if repo_root not in sys.path:
    sys.path.insert(0, repo_root)
print("Added to sys.path:", repo_root)
from fixedincomelib import *
print("Fixed Income Library is loaded.")
# Out:
# Added to sys.path: /Users/nirvana/Documents/NYUQuantClub1
# Fixed Income Library is loaded.

# %% [markdown]
# ### Build a Yield Curve

# %%
### de-serialize a pre-built model
path = 'serialized/yc_model.pickle'
yc_model : Model = qfReadModelFromFile(path)
# rebuild model for special dates
value_date = qfDisplayModelValueDate(yc_model)
data_collection = qfGetDataCollectionFromModel(yc_model)
build_method_collection = qfGetBuildMethodCollection(yc_model)
value_date_last_date = '2026-05-26'
yc_model_last_date = qfCreateModel(value_date_last_date, 'YIELD_CURVE', data_collection, build_method_collection)
value_date_expired = '2026-05-27'
yc_model_expired = qfCreateModel(value_date_expired, 'YIELD_CURVE', data_collection, build_method_collection)

# %% [markdown]
# ### Build Product Bullet Cashflow

# %%
### create product bullet cashflow
termination_date = '2026-05-26'
currency = 'USD'
notional = 1e6
long_or_short = 'LONG'
payment_date = qfAddPeriod(termination_date, '2D', 'F', 'USGS')
prod_bullet_cashflow = qfCreateProductBulletCashflow(termination_date, currency, notional, long_or_short)

# %% [markdown]
# ### Build Valuation Parameter Collection

# %%
### create funding index valuation parameters
vp_type = 'FUNDING INDEX PARAMETER'
content = {'Funding Index' : 'SOFR-1B-FLAT'}
fi_vp = qfCreateValuationParameters(vp_type, content)
vp_collection = qfCreateValuationParametersCollection([fi_vp])

# %% [markdown]
# ### Test Valuation

# %%
### test pv and cash
report = qfCreateValueReport(yc_model, prod_bullet_cashflow, vp_collection, 'pvdetailed')
display(report.display())
report_last_date = qfCreateValueReport(yc_model_last_date, prod_bullet_cashflow, vp_collection, 'pvdetailed')
display(report_last_date.display())
report_expired = qfCreateValueReport(yc_model_expired, prod_bullet_cashflow, vp_collection, 'pvdetailed')
display(report_expired.display())
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 ### test pv and cash
# ----> 2 report = qfCreateValueReport(yc_model, prod_bullet_cashflow, vp_collection, 'pvdetailed')
#       3 display(report.display())
#       4 report_last_date = qfCreateValueReport(yc_model_last_date, prod_bullet_cashflow, vp_collection, 'pvdetailed')
#
# File ~/Documents/NYUQuantClub1/fixedincomelib/apis/valuations.py:95, in qfCreateValueReport(model, product, valuation_parameters_collection, request)
#      89 def qfCreateValueReport(
#      90     model : Model,
#      91     product : Product,
#      92     valuation_parameters_collection: ValuationParametersCollection,
#      93     request : str):
# ---> 95     this_report = create_value_report(model, product, valuation_parameters_collection, ValuationRequest.from_string(request))
#      97     return this_report
#
# File ~/Documents/NYUQuantClub1/fixedincomelib/valuation/utilities.py:22, in create_value_report(model, product, valuation_parameters_collection, request)
#      10 def create_value_report(
#      11     model : Model,
#      12     product : Product,
#      13     valuation_parameters_collection: ValuationParametersCollection,
#      14     request : ValuationRequest) -> Any:
#      16     engine = ValuationEngineProductRegistry.new_valuation_engine(
#      17         model,
#      18         product,
#      19         valuation_parameters_collection,
#      20         request)
# ---> 22     engine.calculate_value()
#      23     if request in [ValuationRequest.PV_DETAILED, ValuationRequest.PV, ValuationRequest.CASH]:
#      24         v : PVCashReport = engine.get_value_and_cash()
#
# File ~/Documents/NYUQuantClub1/fixedincomelib/yield_curve/valuation_engine.py:59, in ValuationEngineProductBulletCashflow.calculate_value(self)
#      57 else:
#      58     funding_model : YieldCurve = self.model_
# ---> 59     self.df_ = funding_model.discount_factor(self.funding_index_, self.termination_date_)
#      60     self.value_ = scaler * self.df_
#
# File ~/Documents/NYUQuantClub1/fixedincomelib/yield_curve/yield_curve_model.py:30, in YieldCurve.discount_factor(self, index, expiry_date)
#      28 df = 1.
#      29 if type(index) == FundingIdentifier and index.reference_index is not None:
# ---> 30     ref_component : YieldCurveModelComponent = self.retrieve_model_component(index.reference_index)
#      31     df = ref_component.discount_factor(expiry_date)
#      32 this_component : YieldCurveModelComponent = self.retrieve_model_component(index)
#
# File ~/Documents/NYUQuantClub1/fixedincomelib/model/model.py:206, in Model.retrieve_model_component(self, target)
#     204     return self.components_[target.name()]
#     205 else:
# --> 206     raise Exception(f'This model does not contain {target.name()} component.')
#
# Exception: This model does not contain SOFRON Actual/360 component.

# %%
### test risk
rr_report = qfCreateValueReport(yc_model, prod_bullet_cashflow, vp_collection, 'firstorderrisk')
display(rr_report)
rr_report_last_date= qfCreateValueReport(yc_model_last_date, prod_bullet_cashflow, vp_collection, 'firstorderrisk')
display(rr_report_last_date)
rr_report_expired = qfCreateValueReport(yc_model_expired, prod_bullet_cashflow, vp_collection, 'firstorderrisk')
display(rr_report_expired)
# Out:
# [array([-416464.95176201,       0.        ,       0.        ,
#               0.        ]),
#  array([0., 0., 0.])]
# [array([0., 0., 0., 0.]), array([0., 0., 0.])]
# [array([0., 0., 0., 0.]), array([0., 0., 0.])]

# %%
### test cf report
cf_report = qfCreateValueReport(yc_model, prod_bullet_cashflow, vp_collection, 'cashflowsreport')
display(cf_report.display())
cf_report_last_date= qfCreateValueReport(yc_model_last_date, prod_bullet_cashflow, vp_collection, 'cashflowsreport')
display(cf_report_last_date.display())
cf_report_expired = qfCreateValueReport(yc_model_expired, prod_bullet_cashflow, vp_collection, 'cashflowsreport')
display(cf_report_expired.display())
# Out:
#               PRODUCT_TYPE                 VALUATION_ENGINE_TYPE  LEG_ID  \
# 0  PRODUCT_BULLET_CASHFLOW  ValuationEngineProductBulletCashflow       0
#
#    CASHFLOW_ID  PAY_OR_RECEIVE   NOTIONAL        PAY_DATE  FORECASTED_AMOUNT  \
# 0            0             1.0  1000000.0  May 26th, 2026          1000000.0
#
#               PV  DISCOUNG FACTOR
# 0  987076.022033         0.987076
#               PRODUCT_TYPE                 VALUATION_ENGINE_TYPE  LEG_ID  \
# 0  PRODUCT_BULLET_CASHFLOW  ValuationEngineProductBulletCashflow       0
#
#    CASHFLOW_ID  PAY_OR_RECEIVE   NOTIONAL        PAY_DATE  FORECASTED_AMOUNT  \
# 0            0             1.0  1000000.0  May 26th, 2026          1000000.0
#
#           PV  DISCOUNG FACTOR
# 0  1000000.0              1.0
#               PRODUCT_TYPE                 VALUATION_ENGINE_TYPE  LEG_ID  \
# 0  PRODUCT_BULLET_CASHFLOW  ValuationEngineProductBulletCashflow       0
#
#    CASHFLOW_ID  PAY_OR_RECEIVE   NOTIONAL        PAY_DATE  FORECASTED_AMOUNT  \
# 0            0             1.0  1000000.0  May 26th, 2026                0.0
#
#     PV  DISCOUNG FACTOR
# 0  0.0              1.0
